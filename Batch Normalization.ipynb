# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
mnist = tf.keras.datasets.mnist
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

# %%
# Appying scaling (minmax)

X_valid, X_train = X_train_full[:5000] / 255. , X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000] , y_train_full[5000:]

#scale test data
X_test = X_test / 255.

# %%
LAYERS = [
      tf.keras.layers.Flatten(input_shape = [28,28]),
      tf.keras.layers.Dense(300, kernel_initializer="he_normal"),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.Dense(100, kernel_initializer="he_normal"),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.Dense(10, activation='softmax')

]

model = tf.keras.models.Sequential(LAYERS)

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=1e-3), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 300)               235500
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 300)               0
#
#  dense_7 (Dense)             (None, 100)               30100
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 100)               0
#
#  dense_8 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266610 (1.02 MB)
# Trainable params: 266610 (1.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
start = time.time()

history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))


end = time.time()


#total time
print(f"Runtime of the program is {end - start}")
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 1.5009 - accuracy: 0.6169 - val_loss: 0.9404 - val_accuracy: 0.7956
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7502 - accuracy: 0.8230 - val_loss: 0.6019 - val_accuracy: 0.8546
# Epoch 3/10
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.5498 - accuracy: 0.8597 - val_loss: 0.4796 - val_accuracy: 0.8776
# Epoch 4/10
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4641 - accuracy: 0.8764 - val_loss: 0.4187 - val_accuracy: 0.8908
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4168 - accuracy: 0.8856 - val_loss: 0.3821 - val_accuracy: 0.8980
# Epoch 6/10
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3868 - accuracy: 0.8925 - val_loss: 0.3577 - val_accuracy: 0.9034
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3655 - accuracy: 0.8971 - val_loss: 0.3394 - val_accuracy: 0.9088
# Epoch 8/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3496 - accuracy: 0.9009 - val_loss: 0.3262 - val_accuracy: 0.9116
# Epoch 9/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3368 - accuracy: 0.9042 - val_loss: 0.3146 - val_accuracy: 0.9138
# Epoch 10/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3264 - accuracy: 0.9071 - val_loss: 0.3055 - val_accuracy: 0.9148
# Runtime of the program is 82.77893424034119

# %%
## After batch Normalization

# %%
del model #deleting prev model

# %%
LAYERS = [
      tf.keras.layers.Flatten(input_shape = [28,28]),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Dense(300, kernel_initializer="he_normal"),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Dense(100, kernel_initializer="he_normal"),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Dense(10, activation='softmax')

]

model = tf.keras.models.Sequential(LAYERS)

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=1e-3), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 784)               0
#
#  batch_normalization_3 (Bat  (None, 784)               3136
#  chNormalization)
#
#  dense_9 (Dense)             (None, 300)               235500
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 300)               0
#
#  batch_normalization_4 (Bat  (None, 300)               1200
#  chNormalization)
#
#  dense_10 (Dense)            (None, 100)               30100
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 100)               0
#
#  batch_normalization_5 (Bat  (None, 100)               400
#  chNormalization)
#
#  dense_11 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 271346 (1.04 MB)
# Trainable params: 268978 (1.03 MB)
# Non-trainable params: 2368 (9.25 KB)
# _________________________________________________________________

# %%
start = time.time()

history = model.fit(X_train, y_train, epochs=10,validation_data=(X_valid, y_valid))


end = time.time()


#total time
print(f"Runtime of the program is {end - start}")
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 10s 5ms/step - loss: 0.8508 - accuracy: 0.7401 - val_loss: 0.4833 - val_accuracy: 0.8628
# Epoch 2/10
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.4685 - accuracy: 0.8641 - val_loss: 0.3809 - val_accuracy: 0.8914
# Epoch 3/10
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.4028 - accuracy: 0.8817 - val_loss: 0.3358 - val_accuracy: 0.9030
# Epoch 4/10
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3652 - accuracy: 0.8940 - val_loss: 0.3101 - val_accuracy: 0.9116
# Epoch 5/10
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3399 - accuracy: 0.9007 - val_loss: 0.2926 - val_accuracy: 0.9156
# Epoch 6/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3230 - accuracy: 0.9060 - val_loss: 0.2787 - val_accuracy: 0.9208
# Epoch 7/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3074 - accuracy: 0.9106 - val_loss: 0.2662 - val_accuracy: 0.9242
# Epoch 8/10
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2912 - accuracy: 0.9158 - val_loss: 0.2551 - val_accuracy: 0.9284
# Epoch 9/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2804 - accuracy: 0.9191 - val_loss: 0.2480 - val_accuracy: 0.9288
# Epoch 10/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2726 - accuracy: 0.9205 - val_loss: 0.2425 - val_accuracy: 0.9326
# Runtime of the program is 143.28175234794617
